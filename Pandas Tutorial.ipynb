# %% [markdown]
# # Jupyter Notebook
# ### jupyter is an open-source web application that allows you to create and share documents that contains live code, equations, visualizations and narrative text.
# ### The Notebook has support for over 40 programming languages, including Python, R, Julia and Scala.
# ### Notebooks can be shared with others using email, Dropbox, Github and the Jupyter Notebook Viewer.
# ### Your code can produce rich, interactive output: HTML, images, videos, LaTeX, and custom MIME types.

# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "Name" : ['kapil', 'Raju', 'Deepanker', 'Ashihs'],
    "Marks" : [50,60,70,80],
    "City" : ['Delhi', 'Mumbai', 'Kanpur', 'Barely']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60  Mumbai
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
df.head(2)
# Out:
#     Name  Marks    City
# 0  kapil     50   Delhi
# 1   Raju     60  Mumbai

# %%
df.tail(2)
# Out:
#         Name  Marks    City
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
df.to_csv("Pandasintro")

# %%
df.to_csv("pandasfalse",index=False)

# %%
df.describe()
# Out:
#            Marks
# count   4.000000
# mean   65.000000
# std    12.909944
# min    50.000000
# 25%    57.500000
# 50%    65.000000
# 75%    72.500000
# max    80.000000

# %%
df.head()
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60  Mumbai
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
kapil = pd.read_csv('Outputmissing.csv')

# %%
kapil
# Out:
#                                                    review  rating
# 0       One stop place for every foodie as you get var...     5.0
# 1       Punjab Sweets Corner is a place where you'll f...     5.0
# 2       customer misbehave with me and the sandwich wa...     1.0
# 3       i had worst pizza from this food corner. Quali...     1.0
# 4       I recently visited this place in karol Bagh an...     5.0
# ...                                                   ...     ...
# 103178  Pretty underrated. They serve really great foo...     5.0
# 103179  Tried their family veg combo !! The dal and pa...     4.0
# 103180  Today i tasted thalli from street food it was ...     3.5
# 103181  Random Sunday afternoon at Ambiance Mall. Lunc...     1.0
# 103182  If they would have name this place as Punjab G...     2.0
#
# [103183 rows x 2 columns]

# %%
kapil['review']
# Out:
# 0         One stop place for every foodie as you get var...
# 1         Punjab Sweets Corner is a place where you'll f...
# 2         customer misbehave with me and the sandwich wa...
# 3         i had worst pizza from this food corner. Quali...
# 4         I recently visited this place in karol Bagh an...
#                                 ...
# 103178    Pretty underrated. They serve really great foo...
# 103179    Tried their family veg combo !! The dal and pa...
# 103180    Today i tasted thalli from street food it was ...
# 103181    Random Sunday afternoon at Ambiance Mall. Lunc...
# 103182    If they would have name this place as Punjab G...
# Name: review, Length: 103183, dtype: object

# %%
kapil['review'][5]
# Out:
# 'v. bad khana and payment 2plat but delvari 1 plat payment extara'

# %%
kapil['review'][0] ='nice food'
# Out:
# c:\users\singh\appdata\local\programs\python\python36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
kapil['review'][0]
# Out:
# 'nice food'

# %%
kapil.to_csv('kapilpandas.csv')

# %% [markdown]
# # Pandas

# %% [markdown]
#  Pandas is an open source data analysis library written in python
#
#  It leverages the power and speed of numpy to make data anyalsis and preprocessing easy for data scientists.
#
# It provides rich and highly robust data operations

# %% [markdown]
# ## Pandas has two types of data strcutures:
# ### a.) series : It's a one dimensional array with indexes, it stores a single column or row of data in a datastream
# ### b.) Dataframe : It's tabular spreadsheet like structure representing rows each of which contains one or multiple columns
#
# A one- dimensional array(labeled) capable of holding any type of data - Series.
#
# A two- dimensional data (labeled) structure with columns of potentially different types of data - DataFrame.

# %%
ser = pd.Series(np.random.rand(20))

# %%
ser
# Out:
# 0     0.960726
# 1     0.509067
# 2     0.185109
# 3     0.221089
# 4     0.342142
# 5     0.956355
# 6     0.338500
# 7     0.069289
# 8     0.266230
# 9     0.762218
# 10    0.332000
# 11    0.473747
# 12    0.818198
# 13    0.516913
# 14    0.163808
# 15    0.102368
# 16    0.558186
# 17    0.898364
# 18    0.952281
# 19    0.009381
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf = pd.DataFrame(np.random.rand(334,5), index = np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,0] = 800

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0       800  0.140403  0.891308  0.652862  0.402845
# 1  0.762701  0.092029  0.822223  0.635997  0.923483

# %%
newdf.columns = list("ABCDE")

# %%
newdf
# Out:
#             A         B         C         D         E
# 0         800  0.140403  0.891308  0.652862  0.402845
# 1    0.762701  0.092029  0.822223  0.635997  0.923483
# 2    0.355653  0.501000  0.435500  0.419877  0.340771
# 3    0.405303  0.282025  0.408581  0.184946  0.030735
# 4    0.612724  0.472083  0.423693  0.857959  0.637090
# ..        ...       ...       ...       ...       ...
# 329  0.475366  0.755361  0.722535  0.995816  0.019500
# 330  0.541212  0.802956  0.963448  0.184832  0.319308
# 331  0.310586  0.749219  0.092573  0.997157  0.247490
# 332   0.40039  0.245106  0.041730  0.141616  0.642901
# 333  0.201515  0.100860  0.031656  0.070180  0.663423
#
# [334 rows x 5 columns]

# %%
newdf.loc[0,'A'] = 55555555

# %%
newdf.head(2)
# Out:
#           A         B         C         D         E
# 0  55555555  0.140403  0.891308  0.652862  0.402845
# 1  0.762701  0.092029  0.822223  0.635997  0.923483

# %%
#if we want to delete something from row
newdf.drop(0)
# Out:
#             A         B         C         D         E
# 1    0.762701  0.092029  0.822223  0.635997  0.923483
# 2    0.355653  0.501000  0.435500  0.419877  0.340771
# 3    0.405303  0.282025  0.408581  0.184946  0.030735
# 4    0.612724  0.472083  0.423693  0.857959  0.637090
# 5    0.908691  0.921948  0.648781  0.449663  0.763246
# ..        ...       ...       ...       ...       ...
# 329  0.475366  0.755361  0.722535  0.995816  0.019500
# 330  0.541212  0.802956  0.963448  0.184832  0.319308
# 331  0.310586  0.749219  0.092573  0.997157  0.247490
# 332   0.40039  0.245106  0.041730  0.141616  0.642901
# 333  0.201515  0.100860  0.031656  0.070180  0.663423
#
# [333 rows x 5 columns]

# %%
#if we want to delete something from column
newdf = newdf.drop('E', axis = 1)

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0  55555555  0.140403  0.891308  0.652862
# 1  0.762701  0.092029  0.822223  0.635997
# 2  0.355653  0.501000  0.435500  0.419877
# 3  0.405303  0.282025  0.408581  0.184946
# 4  0.612724  0.472083  0.423693  0.857959

# %%
newdf.loc[[1,2], ['C','D']]
# Out:
#           C         D
# 1  0.822223  0.635997
# 2  0.435500  0.419877

# %%
# to display all rows, use : in first list
newdf.loc[:, ['C','D']]
# Out:
#             C         D
# 0    0.891308  0.652862
# 1    0.822223  0.635997
# 2    0.435500  0.419877
# 3    0.408581  0.184946
# 4    0.423693  0.857959
# ..        ...       ...
# 329  0.722535  0.995816
# 330  0.963448  0.184832
# 331  0.092573  0.997157
# 332  0.041730  0.141616
# 333  0.031656  0.070180
#
# [334 rows x 2 columns]

# %%
# to dsplay all columns, us : in second part
newdf.loc[[1,2], :]
# Out:
#           A         B         C         D
# 1  0.762701  0.092029  0.822223  0.635997
# 2  0.355653  0.501000  0.435500  0.419877

# %%
newdf.loc[(newdf['A']>0.5)]
# Out:
#             A         B         C         D
# 0    55555555  0.140403  0.891308  0.652862
# 1    0.762701  0.092029  0.822223  0.635997
# 4    0.612724  0.472083  0.423693  0.857959
# 5    0.908691  0.921948  0.648781  0.449663
# 6     0.65637  0.812036  0.584806  0.417593
# ..        ...       ...       ...       ...
# 322   0.94299  0.043689  0.192968  0.297491
# 325  0.966939  0.089357  0.637618  0.444514
# 326  0.849091  0.671647  0.917171  0.888339
# 327  0.502461  0.404211  0.746619  0.931954
# 330  0.541212  0.802956  0.963448  0.184832
#
# [157 rows x 4 columns]

# %%
newdf.loc[(newdf['A']>0.5) & newdf['B']>0.4]
# Out:
#             A         B         C         D
# 0    55555555  0.140403  0.891308  0.652862
# 1    0.762701  0.092029  0.822223  0.635997
# 4    0.612724  0.472083  0.423693  0.857959
# 5    0.908691  0.921948  0.648781  0.449663
# 6     0.65637  0.812036  0.584806  0.417593
# ..        ...       ...       ...       ...
# 322   0.94299  0.043689  0.192968  0.297491
# 325  0.966939  0.089357  0.637618  0.444514
# 326  0.849091  0.671647  0.917171  0.888339
# 327  0.502461  0.404211  0.746619  0.931954
# 330  0.541212  0.802956  0.963448  0.184832
#
# [157 rows x 4 columns]

# %%
newdf.head(2)
# Out:
#           A         B         C         D
# 0  55555555  0.140403  0.891308  0.652862
# 1  0.762701  0.092029  0.822223  0.635997

# %%
#if we want to find values using row names then use iloc, [0,3] will find 3rd column value in 0th row
newdf.iloc[0,3]
# Out:
# 0.6528619500067946

# %%
#if we want to find values using indexes,
newdf.loc[0][3]
# Out:
# 0.6528619500067946

# %%
#if i am using ioloc, we can use numbers, but if i use loc, then i have to give names like newdf.loc[[0,5],['B','C']]
newdf.iloc[[0,5],[1,2]]
# Out:
#           B         C
# 0  0.140403  0.891308
# 5  0.921948  0.648781

# %%
newdf.loc[[0,5],['B','C']]
# Out:
#           B         C
# 0  0.140403  0.891308
# 5  0.921948  0.648781

# %%
newdf.head()
# Out:
#           A         B         C         D
# 0  55555555  0.140403  0.891308  0.652862
# 1  0.762701  0.092029  0.822223  0.635997
# 2  0.355653  0.501000  0.435500  0.419877
# 3  0.405303  0.282025  0.408581  0.184946
# 4  0.612724  0.472083  0.423693  0.857959

# %%
#inplace = true,will do modify the original data
newdf.drop(['B','C'],axis=1, inplace=True)

# %%
newdf
# Out:
#             A         D
# 0    55555555  0.652862
# 1    0.762701  0.635997
# 2    0.355653  0.419877
# 3    0.405303  0.184946
# 4    0.612724  0.857959
# ..        ...       ...
# 329  0.475366  0.995816
# 330  0.541212  0.184832
# 331  0.310586  0.997157
# 332   0.40039  0.141616
# 333  0.201515  0.070180
#
# [334 rows x 2 columns]

# %%
newdf.drop([1,5],axis=0, inplace=True)

# %%
newdf.head()
# Out:
#           A         D
# 0  55555555  0.652862
# 2  0.355653  0.419877
# 3  0.405303  0.184946
# 4  0.612724  0.857959
# 6   0.65637  0.417593

# %%
#set index again from 0 to further
newdf.reset_index()
# Out:
#      index         A         D
# 0        0  55555555  0.652862
# 1        2  0.355653  0.419877
# 2        3  0.405303  0.184946
# 3        4  0.612724  0.857959
# 4        6   0.65637  0.417593
# ..     ...       ...       ...
# 327    329  0.475366  0.995816
# 328    330  0.541212  0.184832
# 329    331  0.310586  0.997157
# 330    332   0.40039  0.141616
# 331    333  0.201515  0.070180
#
# [332 rows x 3 columns]

# %%
newdf.head()
# Out:
#           A         D
# 0  55555555  0.652862
# 2  0.355653  0.419877
# 3  0.405303  0.184946
# 4  0.612724  0.857959
# 6   0.65637  0.417593

# %%
#set index again from 0 to further
#using drop = True will not remove the index column
newdf.reset_index(drop=True, inplace=True)

# %%
newdf.head()
# Out:
#           A         D
# 0  55555555  0.652862
# 1  0.355653  0.419877
# 2  0.405303  0.184946
# 3  0.612724  0.857959
# 4   0.65637  0.417593

# %%
newdf['D'].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 327    False
# 328    False
# 329    False
# 330    False
# 331    False
# Name: D, Length: 332, dtype: bool

# %%
newdf.loc[:,['B']] = None
#use always loc function to store the values, if we initialize value directly, the dataframe which is 
# returning inbetween can be view or copy

# %%
newdf
# Out:
#             A         D     B
# 0    55555555  0.652862  None
# 1    0.355653  0.419877  None
# 2    0.405303  0.184946  None
# 3    0.612724  0.857959  None
# 4     0.65637  0.417593  None
# ..        ...       ...   ...
# 327  0.475366  0.995816  None
# 328  0.541212  0.184832  None
# 329  0.310586  0.997157  None
# 330   0.40039  0.141616  None
# 331  0.201515  0.070180  None
#
# [332 rows x 3 columns]

# %%
newdf['B'].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 327    True
# 328    True
# 329    True
# 330    True
# 331    True
# Name: B, Length: 332, dtype: bool

# %%
df = pd.DataFrame({
                    "Name" : ['kapil', 'Raju', 'Deepanker', 'Ashihs'],
                    "Marks" : [50,60,70,80],
                    "City" : ['Delhi', 'Mumbai', 'Kanpur', 'Barely']})

# %%
df.head()
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60  Mumbai
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
df.loc[[1],['City']] = None

# %%
df.head()
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60    None
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
df.dropna()
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
#it will remove the row or column, only if all the values in the row or column i Nan.
df.dropna(how='all')
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60    None
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80  Barely

# %%
df.loc[[3],['City']] = None

# %%
df
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60    None
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80    None

# %%
df.dropna(how='all', axis=1)
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60    None
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80    None

# %%
df
# Out:
#         Name  Marks    City
# 0      kapil     50   Delhi
# 1       Raju     60    None
# 2  Deepanker     70  Kanpur
# 3     Ashihs     80    None

# %%
df.loc[len(df.index),['Name']] = 'kapil'

# %%
df
# Out:
#         Name  Marks    City
# 0      kapil   50.0   Delhi
# 1       Raju   60.0    None
# 2  Deepanker   70.0  Kanpur
# 3     Ashihs   80.0    None
# 4      kapil    NaN     NaN

# %%
#keep=first, will keep the first duplicate record
df.drop_duplicates(subset=['Name'],keep='first')
# Out:
#         Name  Marks    City
# 0      kapil   50.0   Delhi
# 1       Raju   60.0    None
# 2  Deepanker   70.0  Kanpur
# 3     Ashihs   80.0    None

# %%
#keep=last, will keep the last duplicate record
df.drop_duplicates(subset=['Name'],keep='last')
# Out:
#         Name  Marks    City
# 1       Raju   60.0    None
# 2  Deepanker   70.0  Kanpur
# 3     Ashihs   80.0    None
# 4      kapil    NaN     NaN

# %%
df.shape
# Out:
# (5, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Marks   4 non-null      float64
#  2   City    2 non-null      object
# dtypes: float64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df['Name'].value_counts(dropna=False)
# Out:
# kapil        2
# Deepanker    1
# Raju         1
# Ashihs       1
# Name: Name, dtype: int64

# %%
df
# Out:
#         Name  Marks    City
# 0      kapil   50.0   Delhi
# 1       Raju   60.0    None
# 2  Deepanker   70.0  Kanpur
# 3     Ashihs   80.0    None
# 4      kapil    NaN     NaN

# %%
#dropna = True, means only shows not NaN values
df['Marks'].value_counts(dropna=True)
# Out:
# 80.0    1
# 70.0    1
# 60.0    1
# 50.0    1
# Name: Marks, dtype: int64

# %%
#dropna = True, means only shows not NaN values
df['City'].value_counts(dropna=True)
# Out:
# Kanpur    1
# Delhi     1
# Name: City, dtype: int64

# %%
df.notnull()
# Out:
#    Name  Marks   City
# 0  True   True   True
# 1  True   True  False
# 2  True   True   True
# 3  True   True  False
# 4  True  False  False

# %%
df.isnull()
# Out:
#     Name  Marks   City
# 0  False  False  False
# 1  False  False   True
# 2  False  False  False
# 3  False  False   True
# 4  False   True   True

# %%
df.mean()
# Out:
# Marks    65.0
# dtype: float64

# %%
df.count()
# Out:
# Name     5
# Marks    4
# City     2
# dtype: int64

# %%
df.corr()
# Out:
#        Marks
# Marks    1.0

# %%
df.max()
# Out:
# Name     kapil
# Marks       80
# dtype: object

# %%
df.min()
# Out:
# Name     Ashihs
# Marks        50
# dtype: object

# %%
df.median()
# Out:
# Marks    65.0
# dtype: float64

# %%
df.std()
# Out:
# Marks    12.909944
# dtype: float64
